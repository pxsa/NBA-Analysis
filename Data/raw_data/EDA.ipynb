# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "mysql+pymysql://root:7272528234sJ*@localhost:3306/basketball_db"
)

# %%
query = """
SELECT *
FROM player_performance_analysis
"""


df = pd.read_sql(
    query,
    engine
)

# %%
df.head()
# Out:
#    player_id              full_name  season_id team_code team_name  age  \
# 0  hardeja01           James Harden          1       HOU       HOU   30
# 1  lillada01         Damian Lillard          1       POR       POR   29
# 2  antetgi01  Giannis Antetokounmpo          1       MIL       MIL   25
# 3  davisan02          Anthony Davis          1       LAL       LAL   26
# 4  goberru01            Rudy Gobert          1       UTA       UTA   27
#
#    games  games_started  minutes  win_shares  ws_per_48   bpm  vorp  \
# 0     68             68     2483        13.1      0.254   9.6   7.3
# 1     66             66     2474        11.6      0.225   7.5   5.9
# 2     63             63     1917        11.1      0.279  11.5   6.6
# 3     62             62     2131        11.1      0.250   8.0   5.4
# 4     68             68     2333        10.7      0.221   3.6   3.3
#
#    height_cm  weight_kg shoots
# 0        196       99.0   Left
# 1        188       90.0  Right
# ...

# %%
from src.eda import EDA

# %%
eda = EDA(df)

# %%
eda.shape()
# Out:
# (2785, 16)

# %%
eda.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2785 entries, 0 to 2784
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   player_id      2785 non-null   str
#  1   full_name      2785 non-null   str
#  2   season_id      2785 non-null   int64
#  3   team_code      2785 non-null   str
#  4   team_name      2785 non-null   str
#  5   age            2785 non-null   int64
#  6   games          2785 non-null   int64
#  7   games_started  2785 non-null   int64
#  8   minutes        2785 non-null   int64
#  9   win_shares     2785 non-null   float64
#  10  ws_per_48      2785 non-null   float64
#  11  bpm            2785 non-null   float64
#  12  vorp           2785 non-null   float64
#  13  height_cm      2785 non-null   int64
#  14  weight_kg      2785 non-null   float64
#  15  shoots         2785 non-null   str
# dtypes: float64(5), int64(6), str(5)
# memory usage: 348.3 KB

# %%
eda.missing_values()
# Out:
# player_id        0
# full_name        0
# season_id        0
# team_code        0
# team_name        0
# age              0
# games            0
# games_started    0
# minutes          0
# win_shares       0
# ws_per_48        0
# bpm              0
# vorp             0
# height_cm        0
# weight_kg        0
# shoots           0
# dtype: int64

# %%
eda.duplicates()
# Out:
# np.int64(0)

# %%
from importlib import reload
import src.eda

reload(src.eda)

from src.eda import EDA

# %%
eda = EDA(df)

# %%
eda.numerical_summary()
# Out:
#          season_id          age        games  games_started      minutes  \
# count  2785.000000  2785.000000  2785.000000    2785.000000  2785.000000
# mean      3.030521    25.671095    44.445242      20.929982  1011.086894
# std       1.403045     4.171035    24.102108      25.563501   786.472991
# min       1.000000    19.000000     1.000000       0.000000     1.000000
# 25%       2.000000    23.000000    23.000000       0.000000   261.000000
# 50%       3.000000    25.000000    50.000000       7.000000   915.000000
# 75%       4.000000    28.000000    65.000000      39.000000  1682.000000
# max       5.000000    43.000000    84.000000      83.000000  2989.000000
#
#         win_shares    ws_per_48          bpm         vorp    height_cm  \
# count  2785.000000  2785.000000  2785.000000  2785.000000  2785.000000
# mean      2.139282     0.075089    -1.727648     0.509013   198.881149
# std       2.472748     0.105158     5.033769     1.163320     8.373159
# ...

# %%
eda.categorical_summary()
# Out:
# {'team_code': team_code
#  2TM    356
#  MEM     92
#  OKC     90
#  ORL     85
#  WAS     85
#  TOR     84
#  MIA     83
#  CLE     83
#  DAL     82
#  SAS     82
#  SAC     82
#  UTA     81
#  BRK     81
#  IND     81
#  ATL     81
#  NOP     81
#  DET     80
#  CHI     80
#  GSW     80
#  POR     79
#  MIL     77
#  PHI     77
#  BOS     77
#  HOU     76
#  LAL     76
#  PHO     76
#  CHO     76
#  DEN     75
#  NYK     75
#  LAC     73
#  MIN     71
#  3TM     27
#  4TM      1
#  Name: count, dtype: int64,
#  'shoots': shoots
#  Right    2515
#  Left      261
#  Both        9
#  Name: count, dtype: int64}

# %%
eda.correlation()
# Out:
#                season_id       age     games  games_started   minutes  \
# season_id       1.000000  0.017736  0.075163       0.031456  0.049070
# age             0.017736  1.000000  0.126819       0.114061  0.145226
# games           0.075163  0.126819  1.000000       0.639750  0.884627
# games_started   0.031456  0.114061  0.639750       1.000000  0.865853
# minutes         0.049070  0.145226  0.884627       0.865853  1.000000
# win_shares      0.035943  0.196831  0.666527       0.748506  0.797431
# ws_per_48       0.009204  0.146023  0.340968       0.275693  0.323197
# bpm             0.001025  0.164073  0.404168       0.383031  0.440618
# vorp            0.016909  0.185574  0.406097       0.612749  0.598801
# height_cm       0.012814 -0.017606  0.037312       0.067715 -0.001424
# weight_kg      -0.034379  0.132299  0.079739       0.110129  0.050823
#
#                win_shares  ws_per_48       bpm      vorp  height_cm  weight_kg
# ...

# %%
from importlib import reload
import src.eda

reload(src.eda)

from src.eda import EDA

# %%
eda = EDA(df)

# %%
eda.plot_correlation()

# %%
eda.plot_distribution("age")

# %%
eda.plot_distribution("bpm")

# %%
eda.top_players("bpm")
# Out:
# full_name
# Markquis Nowell          43.30
# Ahmad Caver              36.90
# Stanley Umude            23.50
# Tyler Dorsey             17.80
# Joe Johnson              15.00
# Jamal Crawford           15.00
# Shamorie Ponds           13.70
# Nikola Jokić             11.88
# Giannis Antetokounmpo     9.84
# Leonard Miller            9.60
# Name: bpm, dtype: float64

# %%
eda.top_players("win_shares")
# Out:
# full_name
# Nikola Jokić             14.50
# Giannis Antetokounmpo    11.20
# Rudy Gobert              10.62
# Jimmy Butler              9.78
# Domantas Sabonis          9.34
# Joel Embiid               9.32
# Luka Dončić               9.26
# Chet Holmgren             8.90
# James Harden              8.90
# Jayson Tatum              8.78
# Name: win_shares, dtype: float64

# %%
eda.plot_distribution("age")

# %%
eda.plot_distribution("bpm")

# %%
eda.plot_distribution("win_shares")

# %%
eda.plot_distribution("minutes")

# %%
eda.top_players("bpm")
# Out:
# full_name
# Markquis Nowell          43.30
# Ahmad Caver              36.90
# Stanley Umude            23.50
# Tyler Dorsey             17.80
# Joe Johnson              15.00
# Jamal Crawford           15.00
# Shamorie Ponds           13.70
# Nikola Jokić             11.88
# Giannis Antetokounmpo     9.84
# Leonard Miller            9.60
# Name: bpm, dtype: float64

# %%
eda.top_players("bpm")
# Out:
# full_name
# Markquis Nowell          43.30
# Ahmad Caver              36.90
# Stanley Umude            23.50
# Tyler Dorsey             17.80
# Joe Johnson              15.00
# Jamal Crawford           15.00
# Shamorie Ponds           13.70
# Nikola Jokić             11.88
# Giannis Antetokounmpo     9.84
# Leonard Miller            9.60
# Name: bpm, dtype: float64

# %%
eda.top_players("win_shares")
# Out:
# full_name
# Nikola Jokić             14.50
# Giannis Antetokounmpo    11.20
# Rudy Gobert              10.62
# Jimmy Butler              9.78
# Domantas Sabonis          9.34
# Joel Embiid               9.32
# Luka Dončić               9.26
# Chet Holmgren             8.90
# James Harden              8.90
# Jayson Tatum              8.78
# Name: win_shares, dtype: float64

# %%
eda.top_players("vorp")
# Out:
# full_name
# Nikola Jokić             8.70
# Giannis Antetokounmpo    6.44
# Luka Dončić              6.20
# LeBron James             4.88
# Joel Embiid              4.74
# James Harden             4.50
# Kawhi Leonard            4.30
# Jayson Tatum             4.28
# Jimmy Butler             4.24
# Domantas Sabonis         4.20
# Name: vorp, dtype: float64

# %%
eda.team_analysis()
# Out:
# team_code
# 2TM    556.2
# BOS    254.8
# MIL    240.9
# DEN    231.8
# PHO    222.0
# PHI    211.2
# MIA    211.2
# LAC    210.0
# DAL    203.4
# UTA    203.4
# NOP    197.8
# LAL    192.6
# MEM    192.3
# GSW    191.7
# NYK    188.8
# ATL    180.3
# TOR    178.7
# CHI    177.8
# OKC    174.0
# CLE    173.2
# MIN    171.3
# SAC    166.1
# IND    161.2
# BRK    158.2
# ORL    144.4
# HOU    139.3
# SAS    137.8
# POR    133.1
# WAS    123.9
# CHO    122.1
# DET     94.2
# 3TM     13.5
# 4TM      0.7
# Name: win_shares, dtype: float64
